# %%
import pandas as pd
df = pd.read_csv('../OMDB/OMDB.csv')
df1 = df[df.Metascore.notnull()]
print (df1.shape)
# Out:
# (1705, 27)

# %%
rating = df1['Ratings']
rating_df=pd.DataFrame(columns=['Rank','imdb','rotten_tomatoes','metacritic'])
for x,y in rating.items():
    print (y[141:143])   
    #print((x),y[49:52],y[99:101],y[141:143])
    #rating_df.append(list)
   
#print (rating_df.head())
# Out:
# 84
# 64
# 59
# 67
#
# 65
# 68
# 69
#
# 42
# 42
# 64
# 65
# 65
# 44
# 68
#
# 50
# 53
# 69
# 51
# 53
# 77
#
# 58
# 8/
# 71
# 83
# 62
# 18
# 56
# 53
# 83
#
# 83
# 56
# 63
# 66
#
# 50
# 61
# 58
# 42
# 68
# 40
# 74
# 44
# 57
# 69
# 38
# 72
# 94
#
# 47
# 57
# 36
# 72
# 50
#
# 49
# 75
# 55
# 52
# 10
#
# 71
#
# 87
# 72
# 86
#
# 73
# 87
# 72
# 58
# 66
#
# 82
# 66
#
# 68
# 60
# 31
# 47
# 64
# 65
# 67
#
# 43
# 55
# 61
# 86
# 64
# 55
# 75
# 64
# 56
# 57
# 53
# 50
# 55
# 44
# 63
# 55
# 49
#
# 47
# 42
# 50
# 55
# 70
# 56
# 51
# 48
# 60
# 17
# 68
# 40
# 57
#
# 41
# 48
# 50
# 73
# 75
# 54
# 64
# 57
# 69
# 61
#
# 68
# 59
# 63
#
# 62
# 81
# 64
# 64
# 64
# 45
# 79
# 60
# 24
# 63
# 34
# 48
# 43
# 63
# 42
# 69
# 65
# 60
# 52
# 45
# 58
# 77
# 54
# 65
# 53
# 46
# 37
# 51
# 55
# 68
# 32
# 70
# 6/
# 42
# 62
#
# 35
# 78
# 1/
# 57
# 53
# 48
# 51
#
# 27
# 41
# 77
# 59
# 43
# 91
# 46
# 32
# 57
# 77
# 56
# 67
# 65
#
# 60
# 55
# 70
# 54
# 49
# 53
# 60
# 73
# 52
# 62
# 78
# 12
#
# 43
# 70
# 56
# 12
# 53
# 59
# 58
# ...
